# %%
import sys
import os
import numpy as np

# %%
LIB = os.getcwd().replace('datasets/ToxValDB','')

# %%
if not LIB in sys.path:
    sys.path.insert(0,LIB)

# %%
from logger import setup_applevel_logger

# %%
log = setup_applevel_logger(file_name ='logs/prepare_dataset_ToxVal_sdf.log')

from pathlib import Path
import pandas as pd
from rdkit import Chem
import json
from collections import Counter
from tqdm import tqdm
import openpyxl

from cheminformatics.rdkit_toolkit import convert_smiles_to_mol, Rdkit_operation
from rdkit.Chem.MolStandardize import rdMolStandardize
# Out:
# 2024-07-12 10:30:39,392 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - Converting smiles to rdkit molecules

# %%
# pandas display options
# do not fold dataframes
pd.set_option('expand_frame_repr',False)
# maximum number of columns
pd.set_option("display.max_columns",50)
# maximum number of rows
pd.set_option("display.max_rows",500)
# precision of float numbers
pd.set_option("display.precision",3)
# maximum column width
pd.set_option("max_colwidth", 250)

# enable pandas copy-on-write
pd.options.mode.copy_on_write = True

# %%
# read the ToxVal dataset,as extracted from ToxVal9.5_2024_07_02
inpf = Path(r'genetox_data_ToxVal_110724_v1.xlsx')
tox_data = pd.read_excel(inpf, index_col = [0])

# %%
tox_data = (tox_data
  .assign( result=lambda x: np.where(x.assay_result == 'positive', 1, 
                     np.where(x.assay_result == 'negative', 0, np.nan)))
          .dropna(subset = ['Structure_SMILES'], axis = 0)
         )

# %%
datapoint_ID = 0
assay_results = []
errors = []
for index, row in tox_data.iterrows():
    assay_result = {'datapoint ID': datapoint_ID}
    assay_result['assay'] = row['assay_type_standard']
    assay_result['endpoint'] = row['assay_type_standard']
    assay_result['parsing notes'] = []
    smiles = row['smiles'] = row['Structure_SMILES']
    mol, error_warning = convert_smiles_to_mol(smiles, sanitize=False)
    if mol is not None:
        try:
            mol = rdMolStandardize.Cleanup(mol)  # default rdKit cleanup
        except Exception as error:
            errors.append(error)
            
            assay_result['parsing notes'].append('parsing initial SMILES: ' + error_warning)
    else:
        log.info(f'could not read molecule {index} from {inpf}')

    # standardise and compute the InChi and InChiKey
    if mol:
        with Rdkit_operation() as sio:
            smiles = Chem.MolToSmiles(mol).strip()  # canonical smiles
            error_warning = sio.getvalue()
        if error_warning:
            assay_result['parsing notes'].append('parsing molecule in rdKit: ' + error_warning)
        if pd.isnull(smiles) or len(smiles) == 0:
            smiles = None
            assay_result['parsing notes'].append('empty smiles')
        assay_result['smiles (canonical)'] = smiles

    # fetch the DTXSID number
    assay_result['dtxsid'] = row['dtxsid']

    # genotoxicity outcome
    genotoxicity = row['assay_result']
    assay_result['genotoxicity'] = genotoxicity
    if pd.isnull(genotoxicity) or genotoxicity not in [0, 1]:
        log.warning(f'no genotoxicity data in row {index}')
        assay_result['parsing notes'].append('no genotoxicity outcome')

    # append the datapoint increment counter
    assay_result['parsing notes'] = '; '.join(assay_result['parsing notes'])
    assay_results.append(assay_result)
    datapoint_ID += 1
assay_results = pd.DataFrame(assay_results).reset_index(drop=True)
assay_results['parsing notes'] = assay_results['parsing notes'].replace('', None)

tmp = (assay_results.groupby(['smiles (canonical)', 'assay'])['genotoxicity'].nunique()>1).rename('conflicting outcomes (assay)').reset_index()
assay_results = assay_results.merge(tmp, on=['smiles (canonical)', 'assay'], how='left')
log.info(f'assay/structure combinations with multiple calls: {assay_results["conflicting outcomes (assay)"].sum()}')
tmp = (assay_results.groupby(['smiles (canonical)', 'endpoint'])['genotoxicity'].nunique()>1).rename('conflicting outcomes (endpoint)').reset_index()
assay_results = assay_results.merge(tmp, on=['smiles (canonical)', 'endpoint'], how='left')
log.info(f'endpoint/structure combinations with multiple calls: {assay_results["conflicting outcomes (endpoint)"].sum()}')
# set the molecule ID
tmp = assay_results['smiles (canonical)'].dropna().drop_duplicates().reset_index().rename({'index': 'molecule ID'}, axis='columns').fillna('-').astype(str)
assay_results = assay_results.merge(tmp, on='smiles (canonical)', how='left')
# Out:
# 2024-07-12 10:23:42,528 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,530 - GNN_muta - WARNING - no genotoxicity data in row 0
# 2024-07-12 10:23:42,532 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,534 - GNN_muta - WARNING - no genotoxicity data in row 1
# 2024-07-12 10:23:42,535 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,537 - GNN_muta - WARNING - no genotoxicity data in row 2
# 2024-07-12 10:23:42,539 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,540 - GNN_muta - WARNING - no genotoxicity data in row 3
# 2024-07-12 10:23:42,542 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,545 - GNN_muta - WARNING - no genotoxicity data in row 4
# 2024-07-12 10:23:42,546 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,548 - GNN_muta - WARNING - no genotoxicity data in row 5
# 2024-07-12 10:23:42,549 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,551 - GNN_muta - WARNING - no genotoxicity data in row 6
# 2024-07-12 10:23:42,553 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,555 - GNN_muta - WARNING - no genotoxicity data in row 7
# 2024-07-12 10:23:42,557 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,559 - GNN_muta - WARNING - no genotoxicity data in row 8
# 2024-07-12 10:23:42,561 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,563 - GNN_muta - WARNING - no genotoxicity data in row 9
# 2024-07-12 10:23:42,564 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,566 - GNN_muta - WARNING - no genotoxicity data in row 10
# 2024-07-12 10:23:42,568 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,571 - GNN_muta - WARNING - no genotoxicity data in row 11
# 2024-07-12 10:23:42,572 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,575 - GNN_muta - WARNING - no genotoxicity data in row 12
# 2024-07-12 10:23:42,577 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,579 - GNN_muta - WARNING - no genotoxicity data in row 13
# 2024-07-12 10:23:42,580 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,582 - GNN_muta - WARNING - no genotoxicity data in row 14
# 2024-07-12 10:23:42,584 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,587 - GNN_muta - WARNING - no genotoxicity data in row 15
# 2024-07-12 10:23:42,588 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,590 - GNN_muta - WARNING - no genotoxicity data in row 16
# 2024-07-12 10:23:42,592 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,594 - GNN_muta - WARNING - no genotoxicity data in row 17
# 2024-07-12 10:23:42,595 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,597 - GNN_muta - WARNING - no genotoxicity data in row 18
# 2024-07-12 10:23:42,598 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,600 - GNN_muta - WARNING - no genotoxicity data in row 19
# 2024-07-12 10:23:42,602 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,604 - GNN_muta - WARNING - no genotoxicity data in row 20
# 2024-07-12 10:23:42,605 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,607 - GNN_muta - WARNING - no genotoxicity data in row 21
# 2024-07-12 10:23:42,608 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,611 - GNN_muta - WARNING - no genotoxicity data in row 22
# 2024-07-12 10:23:42,612 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,614 - GNN_muta - WARNING - no genotoxicity data in row 23
# 2024-07-12 10:23:42,615 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,617 - GNN_muta - WARNING - no genotoxicity data in row 24
# 2024-07-12 10:23:42,618 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,620 - GNN_muta - WARNING - no genotoxicity data in row 25
# 2024-07-12 10:23:42,621 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,622 - GNN_muta - WARNING - no genotoxicity data in row 26
# 2024-07-12 10:23:42,623 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,626 - GNN_muta - WARNING - no genotoxicity data in row 27
# 2024-07-12 10:23:42,627 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,629 - GNN_muta - WARNING - no genotoxicity data in row 28
# 2024-07-12 10:23:42,630 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,632 - GNN_muta - WARNING - no genotoxicity data in row 29
# 2024-07-12 10:23:42,633 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,635 - GNN_muta - WARNING - no genotoxicity data in row 30
# 2024-07-12 10:23:42,637 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,638 - GNN_muta - WARNING - no genotoxicity data in row 31
# 2024-07-12 10:23:42,639 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles NC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,641 - GNN_muta - WARNING - no genotoxicity data in row 32
# 2024-07-12 10:23:42,642 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,644 - GNN_muta - WARNING - no genotoxicity data in row 33
# 2024-07-12 10:23:42,645 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,647 - GNN_muta - WARNING - no genotoxicity data in row 34
# 2024-07-12 10:23:42,649 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,651 - GNN_muta - WARNING - no genotoxicity data in row 35
# 2024-07-12 10:23:42,652 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,656 - GNN_muta - WARNING - no genotoxicity data in row 36
# 2024-07-12 10:23:42,658 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,660 - GNN_muta - WARNING - no genotoxicity data in row 37
# 2024-07-12 10:23:42,662 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,664 - GNN_muta - WARNING - no genotoxicity data in row 38
# 2024-07-12 10:23:42,665 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OS(=O)C1=CC=C(Cl)C=C1 to mol
# 2024-07-12 10:23:42,667 - GNN_muta - WARNING - no genotoxicity data in row 39
# 2024-07-12 10:23:42,669 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles COC1=CC=C(C=C1)C(C)=O to mol
# 2024-07-12 10:23:42,672 - GNN_muta - WARNING - no genotoxicity data in row 40
# 2024-07-12 10:23:42,673 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles COC1=CC=C(C=C1)C(C)=O to mol
# 2024-07-12 10:23:42,676 - GNN_muta - WARNING - no genotoxicity data in row 41
# 2024-07-12 10:23:42,678 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles COC1=CC=C(C=C1)C(C)=O to mol
# 2024-07-12 10:23:42,681 - GNN_muta - WARNING - no genotoxicity data in row 42
# 2024-07-12 10:23:42,683 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles COC1=CC=C(C=C1)C(Cl)=O to mol
# 2024-07-12 10:23:42,686 - GNN_muta - WARNING - no genotoxicity data in row 43
# 2024-07-12 10:23:42,688 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles COC1=CC=C(C=C1)C(Cl)=O to mol
# 2024-07-12 10:23:42,690 - GNN_muta - WARNING - no genotoxicity data in row 44
# 2024-07-12 10:23:42,692 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles N[C@@H](CCCCNC(=O)C(F)(F)F)C(O)=O to mol
# 2024-07-12 10:23:42,694 - GNN_muta - WARNING - no genotoxicity data in row 45
# 2024-07-12 10:23:42,696 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles COC1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,698 - GNN_muta - WARNING - no genotoxicity data in row 46
# 2024-07-12 10:23:42,700 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles COC1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,703 - GNN_muta - WARNING - no genotoxicity data in row 47
# 2024-07-12 10:23:42,705 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles COC1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,707 - GNN_muta - WARNING - no genotoxicity data in row 48
# 2024-07-12 10:23:42,709 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles COC1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,711 - GNN_muta - WARNING - no genotoxicity data in row 49
# 2024-07-12 10:23:42,713 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CN(C)C1=CC=C(C=O)C=C1 to mol
# 2024-07-12 10:23:42,717 - GNN_muta - WARNING - no genotoxicity data in row 50
# 2024-07-12 10:23:42,718 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCC(O)C(N)CC to mol
# 2024-07-12 10:23:42,721 - GNN_muta - WARNING - no genotoxicity data in row 51
# 2024-07-12 10:23:42,722 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCC(O)C(N)CC to mol
# 2024-07-12 10:23:42,724 - GNN_muta - WARNING - no genotoxicity data in row 52
# 2024-07-12 10:23:42,726 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCC(O)C(N)CC to mol
# 2024-07-12 10:23:42,728 - GNN_muta - WARNING - no genotoxicity data in row 53
# 2024-07-12 10:23:42,730 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCC(O)C(N)CC to mol
# 2024-07-12 10:23:42,733 - GNN_muta - WARNING - no genotoxicity data in row 54
# 2024-07-12 10:23:42,734 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCC(O)C(N)CC to mol
# 2024-07-12 10:23:42,737 - GNN_muta - WARNING - no genotoxicity data in row 55
# 2024-07-12 10:23:42,738 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCC(O)C(N)CC to mol
# 2024-07-12 10:23:42,740 - GNN_muta - WARNING - no genotoxicity data in row 56
# 2024-07-12 10:23:42,741 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCC(O)C(N)CC to mol
# 2024-07-12 10:23:42,744 - GNN_muta - WARNING - no genotoxicity data in row 57
# 2024-07-12 10:23:42,747 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCC(O)C(N)CC to mol
# 2024-07-12 10:23:42,749 - GNN_muta - WARNING - no genotoxicity data in row 58
# 2024-07-12 10:23:42,751 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [O-][N+](=O)C1=CC=C(CCl)C=C1 to mol
# 2024-07-12 10:23:42,753 - GNN_muta - WARNING - no genotoxicity data in row 59
# 2024-07-12 10:23:42,755 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CNC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,757 - GNN_muta - WARNING - no genotoxicity data in row 67
# 2024-07-12 10:23:42,759 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CNC1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,761 - GNN_muta - WARNING - no genotoxicity data in row 68
# 2024-07-12 10:23:42,765 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O
- GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC(C)C1=CC=C(C=C1)C(C)C to mol
# 2024-07-12 10:23:42,805 - GNN_muta - WARNING - no genotoxicity data in row 75
# 2024-07-12 10:23:42,806 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC(=O)C1=CC=C(C=C1)[N+]([O-])=O to mol
# 2024-07-12 10:23:42,808 - GNN_muta - WARNING - no genotoxicity data in row 76
# 2024-07-12 10:23:42,810 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles ClC(=O)C1=CC=C(C=C1)C(Cl)=O to mol
# 2024-07-12 10:23:42,812 - GNN_muta - WARNING - no genotoxicity data in row 77
# 2024-07-12 10:23:42,815 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles ClC(=O)C1=CC=C(C=C1)C(Cl)=O to mol
# 2024-07-12 10:23:42,816 - GNN_muta - WARNING - no genotoxicity data in row 78
# 2024-07-12 10:23:42,818 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles ClC(=O)C1=CC=C(C=C1)C(Cl)=O to mol
# 2024-07-12 10:23:42,820 - GNN_muta - WARNING - no genotoxicity data in row 79
# 2024-07-12 10:23:42,821 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC(=O)C1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,823 - GNN_muta - WARNING - no genotoxicity data in row 85
# 2024-07-12 10:23:42,824 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC(=O)C1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,827 - GNN_muta - WARNING - no genotoxicity data in row 86
# 2024-07-12 10:23:42,829 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC(=O)C1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,831 - GNN_muta - WARNING - no genotoxicity data in row 87
# 2024-07-12 10:23:42,833 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC(=O)C1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,834 - GNN_muta - WARNING - no genotoxicity data in row 88
# 2024-07-12 10:23:42,836 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC(=O)C1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,839 - GNN_muta - WARNING - no genotoxicity data in row 89
# 2024-07-12 10:23:42,840 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC(=O)C1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,842 - GNN_muta - WARNING - no genotoxicity data in row 90
# 2024-07-12 10:23:42,844 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC(=O)C1=CC=C(C=C1)C(O)=O to mol
# 2024-07-12 10:23:42,847 - GNN_muta - WARNING - no genotoxicity data in row 91
# 2024-07-12 10:23:42,849 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CN(C)C1=CC=C(C=C1)N(C)C to mol
# 2024-07-12 10:23:42,852 - GNN_muta - WARNING - no genotoxicity data in row 92
# 2024-07-12 10:23:42,853 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCCCCC(OC)OC to mol
# 2024-07-12 10:23:42,855 - GNN_muta - WARNING - no genotoxicity data in row 93
# 2024-07-12 10:23:42,857 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCCCCC(OC)OC to mol
# 2024-07-12 10:23:42,859 - GNN_muta - WARNING - no genotoxicity data in row 94
# 2024-07-12 10:23:42,861 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CCCCCCCC(OC)OC to mol
# 2024-07-12 10:23:42,864 - GNN_muta - WARNING - no genotoxicity data in row 95
# 2024-07-12 10:23:42,866 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,868 - GNN_muta - WARNING - no genotoxicity data in row 96
# 2024-07-12 10:23:42,870 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,873 - GNN_muta - WARNING - no genotoxicity data in row 97
# 2024-07-12 10:23:42,874 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,876 - GNN_muta - WARNING - no genotoxicity data in row 98
# 2024-07-12 10:23:42,878 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,880 - GNN_muta - WARNING - no genotoxicity data in row 99
# 2024-07-12 10:23:42,882 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,885 - GNN_muta - WARNING - no genotoxicity data in row 100
# 2024-07-12 10:23:42,887 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,889 - GNN_muta - WARNING - no genotoxicity data in row 101
# 2024-07-12 10:23:42,891 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,893 - GNN_muta - WARNING - no genotoxicity data in row 102
# 2024-07-12 10:23:42,895 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,897 - GNN_muta - WARNING - no genotoxicity data in row 103
# 2024-07-12 10:23:42,899 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,901 - GNN_muta - WARNING - no genotoxicity data in row 104
# 2024-07-12 10:23:42,903 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,906 - GNN_muta - WARNING - no genotoxicity data in row 105
# 2024-07-12 10:23:42,908 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,910 - GNN_muta - WARNING - no genotoxicity data in row 106
# 2024-07-12 10:23:42,911 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles [Ba++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:42,914 - GNN_muta - WARNING - no genotoxicity data in row 107
# 2024-07-12 10:23:42,915 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=C(CCOP(O)(O)=O)SC=[N+]1CC1=CN=C(C)N=C1N to mol
# 2024-07-12 10:23:42,919 - GNN_muta - WARNING - no genotoxicity data in row 108
# 2024-07-12 10:23:42,920 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=C(CCOP(O)(O)=O)SC=[N+]1CC1=CN=C(C)N=C1N to mol
# 2024-07-12 10:23:42,922 - GNN_muta - WARNING - no genotoxicity data in row 109
# 2024-07-12 10:23:42,924 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=C(CCOP(O)(O)=O)SC=[N+]1CC1=CN=C(C)N=C1N to mol
# 2024-07-12 10:23:42,927 - GNN_muta - WARNING - no genotoxicity data in row 110
# 2024-07-12 10:23:42,928 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Nd](Cl)Cl to mol
# 2024-07-12 10:23:42,930 - GNN_muta - WARNING - no genotoxicity data in row 111
# 2024-07-12 10:23:42,932 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl
- GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,010 - GNN_muta - WARNING - no genotoxicity data in row 131
# 2024-07-12 10:23:43,012 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,014 - GNN_muta - WARNING - no genotoxicity data in row 132
# 2024-07-12 10:23:43,016 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,018 - GNN_muta - WARNING - no genotoxicity data in row 133
# 2024-07-12 10:23:43,020 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,022 - GNN_muta - WARNING - no genotoxicity data in row 134
# 2024-07-12 10:23:43,023 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,025 - GNN_muta - WARNING - no genotoxicity data in row 135
# 2024-07-12 10:23:43,027 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,029 - GNN_muta - WARNING - no genotoxicity data in row 136
# 2024-07-12 10:23:43,030 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,033 - GNN_muta - WARNING - no genotoxicity data in row 137
# 2024-07-12 10:23:43,034 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,036 - GNN_muta - WARNING - no genotoxicity data in row 138
# 2024-07-12 10:23:43,037 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,040 - GNN_muta - WARNING - no genotoxicity data in row 139
# 2024-07-12 10:23:43,041 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,043 - GNN_muta - WARNING - no genotoxicity data in row 140
# 2024-07-12 10:23:43,045 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,047 - GNN_muta - WARNING - no genotoxicity data in row 141
# 2024-07-12 10:23:43,048 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,050 - GNN_muta - WARNING - no genotoxicity data in row 142
# 2024-07-12 10:23:43,052 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,054 - GNN_muta - WARNING - no genotoxicity data in row 143
# 2024-07-12 10:23:43,055 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,057 - GNN_muta - WARNING - no genotoxicity data in row 144
# 2024-07-12 10:23:43,059 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,061 - GNN_muta - WARNING - no genotoxicity data in row 145
# 2024-07-12 10:23:43,063 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,065 - GNN_muta - WARNING - no genotoxicity data in row 146
# 2024-07-12 10:23:43,067 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,070 - GNN_muta - WARNING - no genotoxicity data in row 147
# 2024-07-12 10:23:43,071 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Cr](Cl)Cl to mol
# 2024-07-12 10:23:43,074 - GNN_muta - WARNING - no genotoxicity data in row 148
# 2024-07-12 10:23:43,075 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[SiH](Cl)Cl to mol
# 2024-07-12 10:23:43,078 - GNN_muta - WARNING - no genotoxicity data in row 149
# 2024-07-12 10:23:43,080 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[SiH](Cl)Cl to mol
# 2024-07-12 10:23:43,082 - GNN_muta - WARNING - no genotoxicity data in row 150
# 2024-07-12 10:23:43,084 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[SiH](Cl)Cl to mol
# 2024-07-12 10:23:43,085 - GNN_muta - WARNING - no genotoxicity data in row 151
# 2024-07-12 10:23:43,087 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[SiH](Cl)Cl to mol
# 2024-07-12 10:23:43,089 - GNN_muta - WARNING - no genotoxicity data in row 152
# 2024-07-12 10:23:43,090 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[SiH](Cl)Cl to mol
# 2024-07-12 10:23:43,092 - GNN_muta - WARNING - no genotoxicity data in row 153
# 2024-07-12 10:23:43,094 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[SiH](Cl)Cl to mol
# 2024-07-12 10:23:43,096 - GNN_muta - WARNING - no genotoxicity data in row 154
# 2024-07-12 10:23:43,098 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[In](Cl)Cl to mol
# 2024-07-12 10:23:43,100 - GNN_muta - WARNING - no genotoxicity data in row 155
# 2024-07-12 10:23:43,101 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[In](Cl)Cl to mol
# 2024-07-12 10:23:43,103 - GNN_muta - WARNING - no genotoxicity data in row 156
# 2024-07-12 10:23:43,105 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[In](Cl)Cl to mol
# 2024-07-12 10:23:43,107 - GNN_muta - WARNING - no genotoxicity data in row 157
# 2024-07-12 10:23:43,109 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[In](Cl)Cl to mol
# 2024-07-12 10:23:43,111 - GNN_muta - WARNING - no genotoxicity data in row 158
# 2024-07-12 10:23:43,112 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[In](Cl)Cl to mol
# 2024-07-12 10:23:43,114 - GNN_muta - WARNING - no genotoxicity data in row 159
# 2024-07-12 10:23:43,116 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[In](Cl)Cl to mol
# 2024-07-12 10:23:43,118 - GNN_muta - WARNING - no genotoxicity data in row 160
# 2024-07-12 10:23:43,119 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[In](Cl)Cl to mol
# 2024-07-12 10:23:43,122 - GNN_muta - WARNING - no genotoxicity data in row 161
# 2024-07-12 10:23:43,123 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles ClP(Cl)(Cl)=O to mol
# 2024-07-12 10:23:43,125 - GNN_muta - WARNING - no genotoxicity data in row 162
# 2024-07-12 10:23:43,127 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles ClP(Cl)(Cl)=O to mol
# 2024-07-12 10:23:43,129 - GNN_muta - WARNING - no genotoxicity data in row 163
# 2024-07-12 10:23:43,130 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles ClP(Cl)(Cl)=O to mol
# 2024-07-12 10:23:43,133 - GNN_muta - WARNING - no genotoxicity data in row 164
# 2024-07-12 10:23:43,134 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles ClP(Cl)(Cl)=O to mol
# 2024-07-12 10:23:43,137 - GNN_muta - WARNING - no genotoxicity data in row 165
# 2024-07-12 10:23:43,139 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles ClP(Cl)(Cl)=O to mol
# 2024-07-12 10:23:43,141 - GNN_muta - WARNING - no genotoxicity data in row 166
# 2024-07-12 10:23:43,142 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles ClP(Cl)(Cl)=O to mol
# 2024-07-12 10:23:43,145 - GNN_muta - WARNING - no genotoxicity data in row 167
# 2024-07-12 10:23:43,147 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,150 - GNN_muta - WARNING - no genotoxicity data in row 168
# 2024-07-12 10:23:43,151 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,153 - GNN_muta - WARNING - no genotoxicity data in row 169
# 2024-07-12 10:23:43,155 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,156 - GNN_muta - WARNING - no genotoxicity data in row 170
# 2024-07-12 10:23:43,158 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,160 - GNN_muta - WARNING - no genotoxicity data in row 171
# 2024-07-12 10:23:43,161 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,164 - GNN_muta - WARNING - no genotoxicity data in row 172
# 2024-07-12 10:23:43,166 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,168 - GNN_muta - WARNING - no genotoxicity data in row 173
# 2024-07-12 10:23:43,169 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,171 - GNN_muta - WARNING - no genotoxicity data in row 174
# 2024-07-12 10:23:43,173 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,175 - GNN_muta - WARNING - no genotoxicity data in row 175
# 2024-07-12 10:23:43,176 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,177 - GNN_muta - WARNING - no genotoxicity data in row 176
# 2024-07-12 10:23:43,179 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,181 - GNN_muta - WARNING - no genotoxicity data in row 177
# 2024-07-12 10:23:43,184 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Sb](Cl)Cl to mol
# 2024-07-12 10:23:43,186 - GNN_muta - WARNING - no genotoxicity data in row 178
# 2024-07-12 10:23:43,187 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Si](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,189 - GNN_muta - WARNING - no genotoxicity data in row 179
# 2024-07-12 10:23:43,191 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Si](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,193 - GNN_muta - WARNING - no genotoxicity data in row 180
# 2024-07-12 10:23:43,195 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Si](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,197 - GNN_muta - WARNING - no genotoxicity data in row 181
# 2024-07-12 10:23:43,198 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Si](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,201 - GNN_muta - WARNING - no genotoxicity data in row 182
# 2024-07-12 10:23:43,202 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Si](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,205 - GNN_muta - WARNING - no genotoxicity data in row 183
# 2024-07-12 10:23:43,207 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Si](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,209 - GNN_muta - WARNING - no genotoxicity data in row 184
# 2024-07-12 10:23:43,211 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Si](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,213 - GNN_muta - WARNING - no genotoxicity data in row 185
# 2024-07-12 10:23:43,214 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Si](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,216 - GNN_muta - WARNING - no genotoxicity data in row 186
# 2024-07-12 10:23:43,218 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Te](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,221 - GNN_muta - WARNING - no genotoxicity data in row 187
# 2024-07-12 10:23:43,222 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Th](Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,224 - GNN_muta - WARNING - no genotoxicity data in row 188
# 2024-07-12 10:23:43,226 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Nb](Cl)(Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,228 - GNN_muta - WARNING - no genotoxicity data in row 189
# 2024-07-12 10:23:43,230 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Nb](Cl)(Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,233 - GNN_muta - WARNING - no genotoxicity data in row 190
# 2024-07-12 10:23:43,235 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles Cl[Nb](Cl)(Cl)(Cl)Cl to mol
# 2024-07-12 10:23:43,237 - GNN_muta - WARNING - no genotoxicity data in row 191
# 2024-07-12 10:23:43,238 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,240 - GNN_muta - WARNING - no genotoxicity data in row 192
# 2024-07-12 10:23:43,242 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,244 - GNN_muta - WARNING - no genotoxicity data in row 193
# 2024-07-12 10:23:43,246 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,249 - GNN_muta - WARNING - no genotoxicity data in row 194
# 2024-07-12 10:23:43,250 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,252 - GNN_muta - WARNING - no genotoxicity data in row 195
# 2024-07-12 10:23:43,254 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,256 - GNN_muta - WARNING - no genotoxicity data in row 196
# 2024-07-12 10:23:43,258 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,260 - GNN_muta - WARNING - no genotoxicity data in row 197
# 2024-07-12 10:23:43,261 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,263 - GNN_muta - WARNING - no genotoxicity data in row 198
# 2024-07-12 10:23:43,265 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,266 - GNN_muta - WARNING - no genotoxicity data in row 199
# 2024-07-12 10:23:43,269 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,271 - GNN_muta - WARNING - no genotoxicity data in row 200
# 2024-07-12 10:23:43,273 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,275 - GNN_muta - WARNING - no genotoxicity data in row 201
# 2024-07-12 10:23:43,277 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,280 - GNN_muta - WARNING - no genotoxicity data in row 202
# 2024-07-12 10:23:43,281 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,283 - GNN_muta - WARNING - no genotoxicity data in row 203
# 2024-07-12 10:23:43,285 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,288 - GNN_muta - WARNING - no genotoxicity data in row 204
# 2024-07-12 10:23:43,289 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,291 - GNN_muta - WARNING - no genotoxicity data in row 205
# 2024-07-12 10:23:43,293 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,296 - GNN_muta - WARNING - no genotoxicity data in row 206
# 2024-07-12 10:23:43,298 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,301 - GNN_muta - WARNING - no genotoxicity data in row 207
# 2024-07-12 10:23:43,302 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,305 - GNN_muta - WARNING - no genotoxicity data in row 208
# 2024-07-12 10:23:43,307 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,309 - GNN_muta - WARNING - no genotoxicity data in row 209
# 2024-07-12 10:23:43,311 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,313 - GNN_muta - WARNING - no genotoxicity data in row 210
# 2024-07-12 10:23:43,316 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,318 - GNN_muta - WARNING - no genotoxicity data in row 211
# 2024-07-12 10:23:43,320 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,322 - GNN_muta - WARNING - no genotoxicity data in row 212
# 2024-07-12 10:23:43,324 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,326 - GNN_muta - WARNING - no genotoxicity data in row 213
# 2024-07-12 10:23:43,328 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,331 - GNN_muta - WARNING - no genotoxicity data in row 214
# 2024-07-12 10:23:43,333 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,336 - GNN_muta - WARNING - no genotoxicity data in row 215
# 2024-07-12 10:23:43,338 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,340 - GNN_muta - WARNING - no genotoxicity data in row 216
# 2024-07-12 10:23:43,341 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,344 - GNN_muta - WARNING - no genotoxicity data in row 217
# 2024-07-12 10:23:43,345 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,347 - GNN_muta - WARNING - no genotoxicity data in row 218
# 2024-07-12 10:23:43,349 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,351 - GNN_muta - WARNING - no genotoxicity data in row 219
# 2024-07-12 10:23:43,353 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,355 - GNN_muta - WARNING - no genotoxicity data in row 220
# 2024-07-12 10:23:43,357 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,359 - GNN_muta - WARNING - no genotoxicity data in row 221
# 2024-07-12 10:23:43,360 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,362 - GNN_muta - WARNING - no genotoxicity data in row 222
# 2024-07-12 10:23:43,364 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,366 - GNN_muta - WARNING - no genotoxicity data in row 223
# 2024-07-12 10:23:43,367 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,369 - GNN_muta - WARNING - no genotoxicity data in row 224
# 2024-07-12 10:23:43,371 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,373 - GNN_muta - WARNING - no genotoxicity data in row 225
# 2024-07-12 10:23:43,375 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,377 - GNN_muta - WARNING - no genotoxicity data in row 226
# 2024-07-12 10:23:43,379 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# 2024-07-12 10:23:43,381 - GNN_muta - WARNING - no genotoxicity data in row 227
# 2024-07-12 10:23:43,383 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles O.O.O.O.O.O.[Co++].[O-][N+]([O-])=O.[O-][N+]([O-])=O to mol
# ...
# 2024-07-12 10:23:57,623 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=CC=C1 to mol
# 2024-07-12 10:23:57,625 - GNN_muta - WARNING - no genotoxicity data in row 4079
# 2024-07-12 10:23:57,626 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=CC=C1 to mol
# 2024-07-12 10:23:57,628 - GNN_muta - WARNING - no genotoxicity data in row 4080
# 2024-07-12 10:23:57,629 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=CC=C1 to mol
# 2024-07-12 10:23:57,630 - GNN_muta - WARNING - no genotoxicity data in row 4081
# 2024-07-12 10:23:57,632 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=CC=C1 to mol
# 2024-07-12 10:23:57,633 - GNN_muta - WARNING - no genotoxicity data in row 4082
# 2024-07-12 10:23:57,635 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles OC1=CC=CC=C1 to mol
# 2024-07-12 10:23:57
- GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles SC1=CC=CC=C1 to mol
# 2024-07-12 10:23:57,834 - GNN_muta - WARNING - no genotoxicity data in row 4140
# 2024-07-12 10:23:57,835 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,837 - GNN_muta - WARNING - no genotoxicity data in row 4141
# 2024-07-12 10:23:57,839 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,840 - GNN_muta - WARNING - no genotoxicity data in row 4142
# 2024-07-12 10:23:57,842 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,844 - GNN_muta - WARNING - no genotoxicity data in row 4143
# 2024-07-12 10:23:57,845 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,847 - GNN_muta - WARNING - no genotoxicity data in row 4144
# 2024-07-12 10:23:57,848 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,850 - GNN_muta - WARNING - no genotoxicity data in row 4145
# 2024-07-12 10:23:57,851 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,853 - GNN_muta - WARNING - no genotoxicity data in row 4146
# 2024-07-12 10:23:57,854 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,856 - GNN_muta - WARNING - no genotoxicity data in row 4147
# 2024-07-12 10:23:57,858 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,860 - GNN_muta - WARNING - no genotoxicity data in row 4148
# 2024-07-12 10:23:57,862 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,864 - GNN_muta - WARNING - no genotoxicity data in row 4149
# 2024-07-12 10:23:57,865 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,868 - GNN_muta - WARNING - no genotoxicity data in row 4150
# 2024-07-12 10:23:57,870 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CC1=CC=CN=C1 to mol
# 2024-07-12 10:23:57,872 - GNN_muta - WARNING - no genotoxicity data in row 4151
# 2024-07-12 10:23:57,874 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CN1CCNCC1 to mol
# 2024-07-12 10:23:57,875 - GNN_muta - WARNING - no genotoxicity data in row 4152
# 2024-07-12 10:23:57,877 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CN1CCNCC1 to mol
# 2024-07-12 10:23:57,879 - GNN_muta - WARNING - no genotoxicity data in row 4153
# 2024-07-12 10:23:57,881 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CN1CCNCC1 to mol
# 2024-07-12 10:23:57,883 - GNN_muta - WARNING - no genotoxicity data in row 4154
# 2024-07-12 10:23:57,884 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CN1CCNCC1 to mol
# 2024-07-12 10:23:57,886 - GNN_muta - WARNING - no genotoxicity data in row 4155
# 2024-07-12 10:23:57,887 - GNN_muta.cheminformatics.rdkit_toolkit - INFO - successfully converted smiles CN1CCNCC1 to mol

# %%
len(assay_results)
# Out:
# 42475

# %%
assay_results.to_csv('assay_results_120724.csv')

# %%
outf ='/home/grace/Documents/python/GNN/datasets/ToxValDB/processed/tabular'

# %%
log.info('stored assay results in ' + str(outf + 'ToxValDB_genotoxicity.xlsx'))
# Out:
# 2024-07-12 11:45:40,578 - GNN_muta - INFO - stored assay results in /home/grace/Documents/python/GNN/datasets/ToxValDB/processed/tabularToxValDB_genotoxicity.xlsx

# %%
pwd
# Out:
# '/home/grace/Documents/python/GNN/datasets/ToxValDB'

# %%
with pd.ExcelWriter(outf + 'ToxValDB_genotoxicity.xlsx', engine='openpyxl') as writer:
    # detailed
    assay_results.to_excel(writer, sheet_name='genotoxicity detailed')
    # summary (assay level), this eliminates records with null smiles (canonical)
    tmp_cas = assay_results.groupby('smiles (canonical)')['dtxsid'].unique().rename('dtxsid').apply(lambda x: '; '.join(sorted(x))).reset_index()
    tmp = assay_results.copy()
    tmp['genotoxicity'] = assay_results['genotoxicity'].replace({1.0: 'positive', 0.0: 'negative'})
    tmp = tmp[['molecule ID', 'smiles (canonical)', 'endpoint', 'assay', 'genotoxicity']].merge(tmp_cas, on='smiles (canonical)', how='left')
    tmp = tmp.groupby(['molecule ID', 'smiles (canonical)', 'dtxsid', 'endpoint', 'assay'], dropna=False)['genotoxicity'].agg(lambda x: x.dropna().drop_duplicates().to_list()).apply(lambda x: x[0] if len(x)==1 else 'ambiguous' if len(x)>1 else 'not available').reset_index()
    tmp = tmp.pivot(index=['molecule ID', 'smiles (canonical)', 'dtxsid'], columns=['endpoint', 'assay'], values='genotoxicity').fillna('not available').reset_index()
    tmp = tmp.loc[tmp['smiles (canonical)'].notnull()]
    tmp.to_excel(writer, sheet_name='genotoxicity summary (assay)')
    assay_results_assay = tmp.drop(('dtxsid',''), axis='columns')
    cols = [col for col in assay_results_assay.columns if col != ('molecule ID', '') and  col != ('smiles (canonical)', '') ]
    assay_results_assay = assay_results_assay.melt(id_vars=[('molecule ID', ''), ('smiles (canonical)','')], value_vars=cols, value_name='genotoxicity').rename({('smiles (canonical)',''): 'smiles (canonical)', ('molecule ID', ''): 'molecule ID'}, axis='columns').rename({('smiles (canonical)',''):'smiles (canonical)'}, axis='columns')

    # summary (endpoint level), this eliminates records with null smiles (canonical)
    tmp_cas = assay_results.groupby('smiles (canonical)')['dtxsid'].unique().rename('dtxsid').apply(lambda x: '; '.join(sorted(x))).reset_index()
    tmp = assay_results.copy()
    tmp['genotoxicity'] = assay_results['genotoxicity'].replace({1.0: 'positive', 0.0: 'negative'})
    tmp = tmp[['molecule ID', 'smiles (canonical)', 'endpoint', 'genotoxicity']].merge(tmp_cas, on='smiles (canonical)', how='left')
    tmp = tmp.groupby(['molecule ID', 'smiles (canonical)', 'dtxsid', 'endpoint'], dropna=False)['genotoxicity'].agg(lambda x: x.dropna().drop_duplicates().to_list()).apply(lambda x: x[0] if len(x)==1 else 'ambiguous' if len(x)>1 else 'not available').reset_index()
    tmp = tmp.pivot(index=['molecule ID', 'smiles (canonical)', 'dtxsid'], columns='endpoint', values='genotoxicity').fillna('not available').reset_index()
    tmp = tmp.loc[tmp['smiles (canonical)'].notnull()]
    tmp.to_excel(writer, sheet_name='genotoxicity summary (endpoint)')
    assay_results_endpoint = tmp.drop('dtxsid', axis='columns').melt(id_vars=['molecule ID', 'smiles (canonical)'], value_name='genotoxicity')

# %%
outf ='/home/grace/Documents/python/GNN/datasets/ToxValDB/processed/sdf/'

# %%
assay_results_assay
# Out:
#        molecule ID                           smiles (canonical)                         endpoint                            assay   genotoxicity
# 0                0                     O=[N+]([O-])c1ccc(Cl)cc1  bacterial reverse mutation test  bacterial reverse mutation test      ambiguous
# 1            10004         [Na+].[O-]c1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl  bacterial reverse mutation test  bacterial reverse mutation test  not available
# 2            10005            CC1C(C)(C)C2=C(c3ncncc3CC2)C1(C)C  bacterial reverse mutation test  bacterial reverse mutation test       negative
# 3            10010                COc1ccc(C(=O)c2ccccc2O)c(O)c1  bacterial reverse mutation test  bacterial reverse mutation test      ambiguous
# 4            10013            COc1ccc(C(=O)c2ccc(OC)cc2O)c(O)c1  bacterial reverse mutation test  bacterial reverse mutation test  not available
# ...            ...                                          ...                              ...                              ...            ...
# 173509        9982                                  CCN(CCO)N=O             DNA damage (in vivo)             DNA damage (in vivo)  not available
# 173510        9983             [P-3].[P-3].[Zn+2].[Zn+2].[Zn+2]             DNA damage (in vivo)             DNA damage (in vivo)  not available
# 173511        9987                                s1p2sp3p1p3s2             DNA damage (in vivo)             DNA damage (in vivo)  not available
# 173512        9989                                 [Pb+2].[S-2]             DNA damage (in vivo)             DNA damage (in vivo)  not available
# 173513        9995  C=CC(=O)OCCCCOC(=O)Oc1ccc(C(=O)c2ccccc2)cc1             DNA damage (in vivo)             DNA damage (in vivo)  not available
#
# [173514 rows x 5 columns]

# %%
unique_smiles = assay_results['smiles (canonical)'].dropna().unique()

log.info('writing molecules to ' + str(outf + 'ToxValDB_genotoxicity.sdf'))
with Chem.SDWriter(outf + 'ToxValDB_genotoxicity.sdf') as sdf_writer:
    for smiles in tqdm(unique_smiles):
        genotoxicity_outcome_assay = assay_results_assay.loc[assay_results_assay['smiles (canonical)']==smiles].drop('smiles (canonical)', axis='columns').to_json(orient='records')
        genotoxicity_outcome_endpoint = assay_results_endpoint.loc[assay_results_endpoint['smiles (canonical)'] == smiles].drop('smiles (canonical)', axis='columns').to_json(orient='records')
        mol = Chem.MolFromSmiles(smiles)
        mol.SetProp('genotoxicity_assay_level', genotoxicity_outcome_assay)
        mol.SetProp('genotoxicity_endpoint_level', genotoxicity_outcome_endpoint)
        sdf_writer.write(mol)
# Out:
# 2024-07-12 12:03:46,012 - GNN_muta - INFO - writing molecules to /home/grace/Documents/python/GNN/datasets/ToxValDB/processed/sdf/ToxValDB_genotoxicity.sdf
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 9
#       7 genotoxicity_outcome_endpoint = assay_results_endpoint.loc[assay_results_endpoint['smiles (canonical)'] == smiles].drop('smiles (canonical)', axis='columns').to_json(orient='records')
#       8 mol = Chem.MolFromSmiles(smiles)
# ----> 9 mol.SetProp('genotoxicity_assay_level', genotoxicity_outcome_assay)
#      10 mol.SetProp('genotoxicity_endpoint_level', genotoxicity_outcome_endpoint)
#      11 sdf_writer.write(mol)
#
# AttributeError: 'NoneType' object has no attribute 'SetProp'
